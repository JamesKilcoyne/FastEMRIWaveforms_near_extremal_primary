# %%
from few.utils.Extra_for_project.flux_calculations import nex_ELdot,few_ELdot
from few.utils.geodesic import get_separatrix, get_fundamental_frequencies
import numpy as np
import matplotlib.pyplot as plt
from few.utils.mappings.kerrecceq import DELTAPMAX_REGIONC,DELTAPMIN_REGIONC
from few.utils.mappings.jacobian import ELdot_to_PEdot_Jacobian
import pandas as pd
from scipy.interpolate import LinearNDInterpolator

def _EdotPN_alt(p, e):
    """
    https://arxiv.org/pdf/2201.07044.pdf
    eq 91
    """
    oneme2 = (1 - e**2) ** 1.5
    Edot = 32.0 / 5.0 * p ** (-5) * oneme2 * (1 + 73 / 24 * e**2 + 37 / 96 * e**4)
    return Edot

# %%
data_in = np.loadtxt('data/Ollies_flux_data.txt')
columns = ["a", "p", "Edot_tot"]
df = pd.DataFrame(data_in, columns=columns)

# %%
''''
with pd.option_context('display.max_rows', None,
    'display.max_columns', 12,
    'display.width', 13000,
    'display.precision', 10):
        print(df)
'''
# Out:
#                 a          p      Edot_tot
# 0    0.9700000000   1.614100  0.0810252013
# 1    0.9700000000   1.650000  0.0765814741
# 2    0.9700000000   1.700000  0.0708507838
# 3    0.9700000000   1.750000  0.0655821844
# 4    0.9700000000   1.800000  0.0607228037
# 5    0.9700000000   1.900000  0.0520866750
# 6    0.9700000000   2.000000  0.0447116259
# 7    0.9700000000   2.100000  0.0384181171
# 8    0.9700000000   2.200000  0.0330591004
# 9    0.9700000000   2.500000  0.0213055153
# 10   0.9700000000   2.700000  0.0160824179
# 11   0.9700000000   3.000000  0.0107456412
# 12   0.9700000000   3.500000  0.0057728102
# 13   0.9700000000   4.000000  0.0032891084
# 14   0.9980000000   1.236970  0.0903245808
# 15   0.9980000000   1.300000  0.0909807298
# 16   0.9980000000   1.400000  0.0870406102
# 17   0.9980000000   1.500000  0.0798737603
# 18   0.9980000000   1.600000  0.0715488651
# 19   0.9980000000   1.700000  0.0631678415
# 20   0.9980000000   1.800000  0.0552765065
# 21   0.9980000000   1.900000  0.0481117068
# 22   0.9980000000   2.000000  0.0417502257
# 23   0.9980000000   2.200000  0.0313377851
# 24   0.9980000000   2.400000  0.0235620039
# 25   0.9980000000   2.500000  0.0204748495
# 26   0.9980000000   3.000000  0.0104568393
# 27   0.9980000000   3.500000  0.0056569890
# 28   0.9980000000   4.000000  0.0032373139
# 29   0.9980000000   5.000000  0.0012237323
# 30   0.9980000000   6.000000  0.0005376752
# 31   0.9980000000   8.000000  0.0001418519
# 32   0.9980000000  10.000000  0.0000494251
# 33   0.9995000000   1.140366  0.0720455035
# 34   0.9995000000   1.150000  0.0741533079
# 35   0.9995000000   1.180000  0.0795472871
# 36   0.9995000000   1.200000  0.0822518771
# 37   0.9995000000   1.220000  0.0843330755
# 38   0.9995000000   1.250000  0.0864444236
# 39   0.9995000000   1.340918  0.0873816843
# 40   0.9995000000   1.350000  0.0871448655
# 41   0.9995000000   1.367282  0.0865722813
# 42   0.9995000000   1.400000  0.0851131051
# 43   0.9995000000   1.500000  0.0786254899
# 44   0.9995000000   1.600000  0.0707038867
# 45   0.9995000000   1.700000  0.0625764006
# 46   0.9995000000   1.800000  0.0548510307
# 47   0.9995000000   2.000000  0.0415181233
# 48   0.9995000000   2.100000  0.0360023361
# 49   0.9995000000   2.200000  0.0312050053
# 50   0.9995000000   2.300000  0.0270572752
# 51   0.9995000000   2.500000  0.0204120548
# 52   0.9995000000   2.900000  0.0118792391
# 53   0.9995000000   3.000000  0.0104334109
# 54   0.9995000000   3.100000  0.0091850471
# 55   0.9995000000   3.500000  0.0056475333
# 56   0.9995000000   4.000000  0.0032330675
# 57   0.9995000000   4.500000  0.0019455983
# 58   0.9995000000   5.000000  0.0012226445
# 59   0.9995000000   6.000000  0.0005373238
# 60   0.9995000000   8.000000  0.0001417940
# 61   0.9995000000  10.000000  0.0000494110
# 62   0.9999000000   1.078526  0.0494459669
# 63   0.9999000000   1.080000  0.0500738421
# 64   0.9999000000   1.090000  0.0541451225
# 65   0.9999000000   1.100000  0.0578943628
# 66   0.9999000000   1.120000  0.0644857332
# 67   0.9999000000   1.140000  0.0699743620
# 68   0.9999000000   1.150000  0.0723446941
# 69   0.9999000000   1.180000  0.0781361927
# 70   0.9999000000   1.200000  0.0810308135
# 71   0.9999000000   1.220000  0.0832637110
# 72   0.9999000000   1.250000  0.0855528811
# 73   0.9999000000   1.350000  0.0866102227
# 74   0.9999000000   1.400000  0.0846843687
# 75   0.9999000000   1.500000  0.0783376725
# 76   0.9999000000   1.600000  0.0705027542
# 77   0.9999000000   1.700000  0.0624317964
# 78   0.9999000000   1.800000  0.0547448028
# 79   0.9999000000   2.000000  0.0414579429
# 80   0.9999000000   2.100000  0.0359561592
# 81   0.9999000000   2.200000  0.0311691951
# 82   0.9999000000   2.300000  0.0270292401
# 83   0.9999000000   2.500000  0.0203944364
# 84   0.9999000000   2.900000  0.0118716706
# 85   0.9999000000   3.000000  0.0104271905
# 86   0.9999000000   3.100000  0.0091799073
# 87   0.9999000000   3.500000  0.0056450180
# 88   0.9999000000   4.000000  0.0032319370
# 89   0.9999000000   4.500000  0.0019450454
# 90   0.9999000000   5.000000  0.0012223547
# 91   0.9999000000   6.000000  0.0005372301
# 92   0.9999000000   8.000000  0.0001417786
# 93   0.9999000000  10.000000  0.0000494072
# 94   0.9999900000   1.035232  0.0257184747
# 95   0.9999900000   1.040000  0.0286377300
# 96   0.9999900000   1.045000  0.0315882900
# 97   0.9999900000   1.050000  0.0344269561
# 98   0.9999900000   1.060000  0.0397786701
# 99   0.9999900000   1.070000  0.0447153571
# 100  0.9999900000   1.078526  0.0486146618
# 101  0.9999900000   1.080000  0.0492608023
# 102  0.9999900000   1.090000  0.0534384385
# 103  0.9999900000   1.100000  0.0572707812
# 104  0.9999900000   1.120000  0.0639840506
# 105  0.9999900000   1.140000  0.0695580784
# 106  0.9999900000   1.150000  0.0719622410
# 107  0.9999900000   1.180000  0.0778320270
# 108  0.9999900000   1.181765  0.0781201517
# 109  0.9999900000   1.200000  0.0807654591
# 110  0.9999900000   1.220000  0.0830299317
# 111  0.9999900000   1.250000  0.0853567318
# 112  0.9999900000   1.350000  0.0864913405
# 113  0.9999900000   1.400000  0.0845887889
# 114  0.9999900000   1.500000  0.0782733119
# 115  0.9999900000   1.600000  0.0704577020
# 116  0.9999900000   1.700000  0.0623993727
# 117  0.9999900000   1.800000  0.0547209678
# 118  0.9999900000   2.000000  0.0414444286
# 119  0.9999900000   2.100000  0.0359457868
# 120  0.9999900000   2.200000  0.0311611497
# 121  0.9999900000   2.500000  0.0203904764
# 122  0.9999900000   2.900000  0.0118699690
# 123  0.9999900000   3.000000  0.0104257920
# 124  0.9999900000   3.100000  0.0091787516
# 125  0.9999900000   3.500000  0.0056444523
# 126  0.9999900000   4.000000  0.0032316828
# 127  0.9999900000   4.500000  0.0019449211
# 128  0.9999900000   5.000000  0.0012222896
# 129  0.9999900000   6.000000  0.0005372090
# 130  0.9999900000   8.000000  0.0001417751
# 131  0.9999900000  10.000000  0.0000494064
# 132  0.9999990000   1.016095  0.0125584577
# 133  0.9999990000   1.020000  0.0153595213
# 134  0.9999990000   1.030000  0.0221692830
# 135  0.9999990000   1.035000  0.0253824831
# 136  0.9999990000   1.035232  0.0255287980
# 137  0.9999990000   1.040000  0.0284724149
# 138  0.9999990000   1.045000  0.0314427125
# 139  0.9999990000   1.050000  0.0342970204
# 140  0.9999990000   1.060000  0.0396719915
# 141  0.9999990000   1.070000  0.0446251696
# 142  0.9999990000   1.078526  0.0485351768
# 143  0.9999990000   1.080000  0.0491829334
# 144  0.9999990000   1.090000  0.0533701291
# 145  0.9999990000   1.100000  0.0572101096
# 146  0.9999990000   1.120000  0.0639348260
# 147  0.9999990000   1.140000  0.0695170269
# 148  0.9999990000   1.150000  0.0719244581
# 149  0.9999990000   1.180000  0.0778018674
# 150  0.9999990000   1.181765  0.0780903619
# 151  0.9999990000   1.200000  0.0807391061
# 152  0.9999990000   1.220000  0.0830066875
# 153  0.9999990000   1.250000  0.0853372046
# 154  0.9999990000   1.350000  0.0864794804
# 155  0.9999990000   1.400000  0.0845792486
# 156  0.9999990000   1.500000  0.0782668838
# 157  0.9999990000   1.600000  0.0704532009
# 158  0.9999990000   1.700000  0.0623961326
# 159  0.9999990000   1.800000  0.0547185856
# 160  0.9999990000   2.000000  0.0414430777
# 161  0.9999990000   2.100000  0.0359447499
# 162  0.9999990000   2.200000  0.0311603454
# 163  0.9999990000   2.300000  0.0270223107
# 164  0.9999990000   2.500000  0.0203900805
# 165  0.9999990000   2.900000  0.0118697988
# 166  0.9999990000   3.000000  0.0104256521
# 167  0.9999990000   3.100000  0.0091786360
# 168  0.9999990000   3.500000  0.0056443958
# 169  0.9999990000   4.000000  0.0032316574
# 170  0.9999990000   4.500000  0.0019449086
# 171  0.9999990000   5.000000  0.0012222830
# 172  0.9999990000   6.000000  0.0005372069
# 173  0.9999990000   8.000000  0.0001417748
# 174  0.9999990000  10.000000  0.0000494063
# 175  0.9999999000   1.007416  0.0059651820
# 176  0.9999999000   1.010000  0.0079604491
# 177  0.9999999000   1.012000  0.0094785706
# 178  0.9999999000   1.014000  0.0109740133
# 179  0.9999999000   1.016000  0.0124469413
# 180  0.9999999000   1.016095  0.0125166690
# 181  0.9999999000   1.020000  0.0153261568
# 182  0.9999999000   1.030000  0.0221473542
# 183  0.9999999000   1.035000  0.0253638004
# 184  0.9999999000   1.035232  0.0255102436
# 185  0.9999999000   1.040000  0.0284561627
# 186  0.9999999000   1.045000  0.0314283489
# 187  0.9999999000   1.050000  0.0342841672
# 188  0.9999999000   1.060000  0.0396614035
# 189  0.9999999000   1.070000  0.0446162005
# 190  0.9999999000   1.078526  0.0485272630
# 191  0.9999999000   1.080000  0.0491751793
# 192  0.9999999000   1.090000  0.0533633209
# 193  0.9999999000   1.100000  0.0572040588
# 194  0.9999999000   1.120000  0.0639299128
# 195  0.9999999000   1.140000  0.0695129274
# 196  0.9999999000   1.150000  0.0719206844
# 197  0.9999999000   1.180000  0.0777988540
# 198  0.9999999000   1.181765  0.0780873854
# 199  0.9999999000   1.200000  0.0807364726
# 200  0.9999999000   1.220000  0.0830043644
# 201  0.9999999000   1.250000  0.0853352527
# 202  0.9999999000   1.350000  0.0864782947
# 203  0.9999999000   1.400000  0.0845782947
# 204  0.9999999000   1.500000  0.0782662411
# 205  0.9999999000   1.600000  0.0704527508
# 206  0.9999999000   1.700000  0.0623958087
# 207  0.9999999000   1.800000  0.0547183474
# 208  0.9999999000   2.000000  0.0414429426
# 209  0.9999999000   2.100000  0.0359446462
# 210  0.9999999000   2.200000  0.0311602649
# 211  0.9999999000   2.300000  0.0270222477
# 212  0.9999999000   2.500000  0.0203900409
# 213  0.9999999000   2.900000  0.0118697818
# 214  0.9999999000   3.000000  0.0104256381
# 215  0.9999999000   3.100000  0.0091786244
# 216  0.9999999000   3.500000  0.0056443901
# 217  0.9999999000   4.000000  0.0032316548
# 218  0.9999999000   4.500000  0.0019449074
# 219  0.9999999000   5.000000  0.0012222824
# 220  0.9999999000   6.000000  0.0005372067
# 221  0.9999999000   8.000000  0.0001417747
# 222  0.9999999000  10.000000  0.0000494063
# 223  0.9999999900   1.003430  0.0027983076
# 224  0.9999999900   1.004000  0.0032554922
# 225  0.9999999900   1.005000  0.0040532702
# 226  0.9999999900   1.006000  0.0048451566
# 227  0.9999999900   1.007000  0.0056311328
# 228  0.9999999900   1.007416  0.0059560937
# 229  0.9999999900   1.010000  0.0079537423
# 230  0.9999999900   1.012000  0.0094729973
# 231  0.9999999900   1.014000  0.0109692479
# 232  0.9999999900   1.016000  0.0124427811
# 233  0.9999999900   1.016095  0.0125125338
# 234  0.9999999900   1.020000  0.0153228429
# 235  0.9999999900   1.030000  0.0221451680
# 236  0.9999999900   1.035000  0.0253619362
# 237  0.9999999900   1.035232  0.0255083922
# 238  0.9999999900   1.040000  0.0284545402
# 239  0.9999999900   1.045000  0.0314269145
# 240  0.9999999900   1.050000  0.0342828832
# 241  0.9999999900   1.060000  0.0396603456
# 242  0.9999999900   1.070000  0.0446153041
# 243  0.9999999900   1.078526  0.0485264720
# 244  0.9999999900   1.080000  0.0491744042
# 245  0.9999999900   1.090000  0.0533626403
# 246  0.9999999900   1.100000  0.0572034539
# 247  0.9999999900   1.120000  0.0639294216
# 248  0.9999999900   1.140000  0.0695125175
# 249  0.9999999900   1.150000  0.0719203071
# 250  0.9999999900   1.180000  0.0777985527
# 251  0.9999999900   1.181765  0.0780870878
# 252  0.9999999900   1.200000  0.0807362093
# 253  0.9999999900   1.220000  0.0830041321
# 254  0.9999999900   1.250000  0.0853350575
# 255  0.9999999900   1.350000  0.0864781761
# 256  0.9999999900   1.400000  0.0845781994
# 257  0.9999999900   1.500000  0.0782661768
# 258  0.9999999900   1.600000  0.0704527058
# 259  0.9999999900   1.700000  0.0623957763
# 260  0.9999999900   1.800000  0.0547183236
# 261  0.9999999900   2.000000  0.0414429291
# 262  0.9999999900   2.100000  0.0359446359
# 263  0.9999999900   2.200000  0.0311602569
# 264  0.9999999900   2.300000  0.0270222414
# 265  0.9999999900   2.500000  0.0203900369
# 266  0.9999999900   2.900000  0.0118697801
# 267  0.9999999900   3.000000  0.0104256367
# 268  0.9999999900   3.100000  0.0091786233
# 269  0.9999999900   3.500000  0.0056443896
# 270  0.9999999900   4.000000  0.0032316546
# 271  0.9999999900   4.500000  0.0019449073
# 272  0.9999999900   5.000000  0.0012222823
# 273  0.9999999900   6.000000  0.0005372067
# 274  0.9999999900   8.000000  0.0001417747
# 275  0.9999999900  10.000000  0.0000494063
# 276  0.9999999990   1.001590  0.0013052426
# 277  0.9999999990   1.001590  0.0013448140
# 278  0.9999999990   1.002000  0.0016394708
# 279  0.9999999990   1.002000  0.0016886291
# 280  0.9999999990   1.003000  0.0024496598
# 281  0.9999999990   1.003000  0.0025226659
# 282  0.9999999990   1.003430  0.0027963414
# 283  0.9999999990   1.004000  0.0032538082
# 284  0.9999999990   1.004000  0.0033502116
# 285  0.9999999990   1.005000  0.0040519251
# 286  0.9999999990   1.005000  0.0041638787
# 287  0.9999999990   1.006000  0.0048440371
# 288  0.9999999990   1.006000  0.0049859009
# 289  0.9999999990   1.007000  0.0056301743
# 290  0.9999999990   1.007000  0.0057941098
# 291  0.9999999990   1.007416  0.0059551894
# 292  0.9999999990   1.008000  0.0065959495
# 293  0.9999999990   1.010000  0.0079530735
# 294  0.9999999990   1.010000  0.0081806838
# 295  0.9999999990   1.012000  0.0094724410
# 296  0.9999999990   1.012000  0.0097404178
# 297  0.9999999990   1.014000  0.0109687720
# 298  0.9999999990   1.014000  0.0112755279
# 299  0.9999999990   1.016000  0.0124423655
# 300  0.9999999990   1.016000  0.0127863501
# 301  0.9999999990   1.016095  0.0125121207
# 302  0.9999999990   1.020000  0.0153225118
# 303  0.9999999990   1.020000  0.0157364851
# 304  0.9999999990   1.030000  0.0221449494
# 305  0.9999999990   1.030000  0.0227098345
# 306  0.9999999990   1.035000  0.0253617499
# 307  0.9999999990   1.035000  0.0259902801
# 308  0.9999999990   1.035232  0.0255082071
# 309  0.9999999990   1.040000  0.0284543780
# 310  0.9999999990   1.040000  0.0291396073
# 311  0.9999999990   1.045000  0.0314267711
# 312  0.9999999990   1.045000  0.0321622474
# 313  0.9999999990   1.050000  0.0342827549
# 314  0.9999999990   1.050000  0.0350623906
# 315  0.9999999990   1.060000  0.0396602398
# 316  0.9999999990   1.060000  0.0405119511
# 317  0.9999999990   1.070000  0.0446152145
# 318  0.9999999990   1.070000  0.0455200286
# 319  0.9999999990   1.078526  0.0485263929
# 320  0.9999999990   1.080000  0.0491743267
# 321  0.9999999990   1.080000  0.0501160496
# 322  0.9999999990   1.090000  0.0533625722
# 323  0.9999999990   1.090000  0.0543278671
# 324  0.9999999990   1.100000  0.0572033934
# 325  0.9999999990   1.100000  0.0581810876
# 326  0.9999999990   1.120000  0.0639293725
# 327  0.9999999990   1.120000  0.0649046585
# 328  0.9999999990   1.140000  0.0695124765
# 329  0.9999999990   1.140000  0.0704551529
# 330  0.9999999990   1.150000  0.0719202694
# 331  0.9999999990   1.150000  0.0728462369
# 332  0.9999999990   1.180000  0.0777985225
# 333  0.9999999990   1.180000  0.0786387479
# 334  0.9999999990   1.181765  0.0780870580
# 335  0.9999999990   1.200000  0.0807361830
# 336  0.9999999990   1.200000  0.0813643808
# 337  0.9999999990   1.220000  0.0830041088
# 338  0.9999999990   1.220000  0.0837208553
# 339  0.9999999990   1.250000  0.0853350380
# 340  0.9999999990   1.250000  0.0859557377
# 341  0.9999999990   1.300000  0.0873529646
# 342  0.9999999990   1.350000  0.0864781643
# 343  0.9999999990   1.350000  0.0868228949
# 344  0.9999999990   1.400000  0.0845781898
# 345  0.9999999990   1.400000  0.0848141514
# 346  0.9999999990   1.500000  0.0782661704
# 347  0.9999999990   1.500000  0.0783980108
# 348  0.9999999990   1.600000  0.0704527013
# 349  0.9999999990   1.600000  0.0705197414
# 350  0.9999999990   1.700000  0.0623957730
# 351  0.9999999990   1.700000  0.0624172076
# 352  0.9999999990   1.800000  0.0547183212
# 353  0.9999999990   1.800000  0.0547263581
# 354  0.9999999990   1.900000  0.0477000561
# 355  0.9999999990   2.000000  0.0414420698
# 356  0.9999999990   2.000000  0.0414429277
# 357  0.9999999990   2.100000  0.0359406796
# 358  0.9999999990   2.100000  0.0359446348
# 359  0.9999999990   2.200000  0.0311541192
# 360  0.9999999990   2.200000  0.0311602561
# 361  0.9999999990   2.300000  0.0270067369
# 362  0.9999999990   2.300000  0.0270222408
# 363  0.9999999990   2.500000  0.0203865267
# 364  0.9999999990   2.500000  0.0203900366
# 365  0.9999999990   2.900000  0.0118697800
# 366  0.9999999990   2.900000  0.0118698403
# 367  0.9999999990   3.000000  0.0104256366
# 368  0.9999999990   3.000000  0.0104256743
# 369  0.9999999990   3.100000  0.0091786232
# 370  0.9999999990   3.100000  0.0091786470
# 371  0.9999999990   3.500000  0.0056443895
# 372  0.9999999990   3.500000  0.0056443937
# 373  0.9999999990   4.000000  0.0032316545
# 374  0.9999999990   4.000000  0.0032316574
# 375  0.9999999990   4.500000  0.0019449073
# 376  0.9999999990   4.500000  0.0019449074
# 377  0.9999999990   5.000000  0.0012222823
# 378  0.9999999990   5.000000  0.0012222823
# 379  0.9999999990   6.000000  0.0005372067
# 380  0.9999999990   6.000000  0.0005372067
# 381  0.9999999990   8.000000  0.0001417747
# 382  0.9999999990   8.000000  0.0001417747
# 383  0.9999999990  10.000000  0.0000494063
# 384  0.9999999990  10.000000  0.0000494063
# 385  0.9999999999   1.000737  0.0006071868
# 386  0.9999999999   1.001000  0.0008226883
# 387  0.9999999999   1.001590  0.0013048049
# 388  0.9999999999   1.002000  0.0016391231
# 389  0.9999999999   1.003000  0.0024494284
# 390  0.9999999999   1.003430  0.0027961391
# 391  0.9999999999   1.004000  0.0032536348
# 392  0.9999999999   1.005000  0.0040517865
# 393  0.9999999999   1.006000  0.0048439218
# 394  0.9999999999   1.007000  0.0056300756
# 395  0.9999999999   1.007416  0.0059550962
# 396  0.9999999999   1.010000  0.0079530045
# 397  0.9999999999   1.012000  0.0094723837
# 398  0.9999999999   1.014000  0.0109687230
# 399  0.9999999999   1.016000  0.0124423227
# 400  0.9999999999   1.016095  0.0125120782
# 401  0.9999999999   1.020000  0.0153224777
# 402  0.9999999999   1.030000  0.0221449269
# 403  0.9999999999   1.035000  0.0253617307
# 404  0.9999999999   1.035232  0.0255081880
# 405  0.9999999999   1.040000  0.0284543613
# 406  0.9999999999   1.045000  0.0314267563
# 407  0.9999999999   1.050000  0.0342827417
# 408  0.9999999999   1.060000  0.0396602289
# 409  0.9999999999   1.070000  0.0446152052
# 410  0.9999999999   1.078526  0.0485263848
# 411  0.9999999999   1.080000  0.0491743188
# 412  0.9999999999   1.090000  0.0533625653
# 413  0.9999999999   1.100000  0.0572033872
# 414  0.9999999999   1.120000  0.0639293674
# 415  0.9999999999   1.140000  0.0695124723
# 416  0.9999999999   1.150000  0.0719202655
# 417  0.9999999999   1.180000  0.0777985195
# 418  0.9999999999   1.181765  0.0780870550
# 419  0.9999999999   1.200000  0.0807361803
# 420  0.9999999999   1.220000  0.0830041065
# 421  0.9999999999   1.250000  0.0853350360
# 422  0.9999999999   1.350000  0.0864781630
# 423  0.9999999999   1.400000  0.0845781889
# 424  0.9999999999   1.500000  0.0782661697
# 425  0.9999999999   1.600000  0.0704527009
# 426  0.9999999999   1.700000  0.0623957727
# 427  0.9999999999   1.800000  0.0547183210
# 428  0.9999999999   2.000000  0.0414429276
# 429  0.9999999999   2.100000  0.0359446347
# 430  0.9999999999   2.200000  0.0311602560
# 431  0.9999999999   2.300000  0.0270222407
# 432  0.9999999999   2.500000  0.0203900365
# 433  0.9999999999   2.900000  0.0118697799
# 434  0.9999999999   3.000000  0.0104256366
# 435  0.9999999999   3.100000  0.0091786232
# 436  0.9999999999   3.500000  0.0056443895
# 437  0.9999999999   4.000000  0.0032316545
# 438  0.9999999999   4.500000  0.0019449073
# 439  0.9999999999   5.000000  0.0012222823
# 440  0.9999999999   6.000000  0.0005372067
# 441  0.9999999999   8.000000  0.0001417747
# 442  0.9999999999  10.000000  0.0000494063

# %%
Edot_PN = _EdotPN_alt(df["p"],0)

Ollie_Edot_interp_norm = LinearNDInterpolator(list(zip(df["a"], df["p"])), -df["Edot_tot"] / Edot_PN)

def Ollie_Edot_interp(a,p):
    return Ollie_Edot_interp_norm(a,p)*_EdotPN_alt(p,0)

# %% [markdown]
# ### Check exact values in flux file

# %%
def Ollie_flux(a,p):
    match = df[(df.iloc[:, 0] == a) & (df.iloc[:, 1] == p)]
    if not match.empty:
        return match.iloc[0, 2]  # value from the third column
    raise ValueError("no ,a,p value")

a_vals = df["a"]
p_vals = df["p"]
Edot_ollie_arr= df["Edot_tot"]

# %%
Edot_zach = []
Edot_few = []
Edot_ollie = []
for a,p,edot_ollie in zip(a_vals,p_vals,Edot_ollie_arr):
    edot_zach = nex_ELdot(a,p,0,1)[0]
    edot_few = few_ELdot(a,p,0,1)[0]


    if p < get_separatrix(a,0,1)+DELTAPMIN_REGIONC:
        continue

    Edot_few.append(edot_few)
    Edot_zach.append(edot_zach)
    Edot_ollie.append(-edot_ollie)

    rel_diff = np.abs((edot_zach - -edot_ollie)/(edot_zach))

        
Edot_few=np.asarray(Edot_few)
Edot_zach=np.asarray(Edot_zach)
Edot_ollie=np.asarray(Edot_ollie)

# %%
plt.plot(Edot_few)
plt.plot(Edot_zach,".")
plt.plot(Edot_ollie,".")

# %%
rel_diff = np.abs((Edot_zach - Edot_ollie)/(Edot_zach))
plt.plot(rel_diff)

# %%
a,p,e,x = 0.998,10 ,0 ,1
nex_ELdot(a,p,e,x)[0], few_ELdot(a,p,e,x)[0] , Ollie_flux(a,p)
# Out:
# (-4.944353522914345e-05,
#  -4.942512180625564e-05,
#  np.float64(4.942512177217305e-05))

# %% [markdown]
# ### Check interpolated error

# %%
n = 9
a,e,x=1-10**(-n),0,1
psep = get_separatrix(a,e,x)
p= np.linspace(psep+DELTAPMIN_REGIONC,psep+9,10000)
a = np.ones_like(p)*a
e = np.ones_like(p)*e
x = np.ones_like(p)*x

ollie = Ollie_Edot_interp(a,p)
zach = nex_ELdot(a,p,e,x)[0]
few = few_ELdot(a,p,e,x)[0]

rel_diff_OZ = np.abs((ollie-zach)/ollie)
#rel_diff_OF = np.abs((ollie-few)/ollie)
#rel_diff_ZF = np.abs((zach-few)/zach)

fig, axs = plt.subplots(1,2,figsize = (10,5))

x1 = np.log10(p-psep)
x2 = p

axs[0].plot(x1,rel_diff_OZ,label = "ollie-zach")
#plt.plot(p,rel_diff_OF,label = "ollie-few")
#plt.plot(p,rel_diff_ZF,label = "zach-few")

axs[1].plot(x1, ollie,label  = "Ollie")
axs[1].plot(x1, zach,label  = "Zach")

axs[0].legend()
axs[1].legend()

#plt.plot(p,ollie)
#plt.plot(p,zach)

# %%
x=1
n1,n2 =2000,2000
e=0.0

a = 1 - np.logspace(-2, -10, n1)
#a=np.geomspace(0.999,1-10**(-12),n1)
p= np.linspace(1,10,n2)

A, P = np.meshgrid(a, p)
E= np.zeros_like(P)
X= np.ones_like(P)
PSEP = get_separatrix(A.flatten(),E.flatten(),X.flatten())
PSEP = PSEP.reshape(n1,n2)

deltap =   DELTAPMIN_REGIONC

#Add near-extremal data
Z_nex = nex_ELdot(A.flatten(),P.flatten(),E.flatten(),X.flatten())

Z_nex = Z_nex[0].reshape(n1,n2)
Z_nex_masked = np.where(P > PSEP+np.ones_like(PSEP)*deltap, Z_nex, np.nan)


#Add FEW data
Z_few = few_ELdot(A.flatten(),P.flatten(),E.flatten(),X.flatten())

Z_few = Z_few[0].reshape(n1,n2)
Z_few_masked = np.where(P > PSEP+np.ones_like(PSEP)*deltap, Z_few, np.nan)


#Add ollies data
Z_ollie = Ollie_Edot_interp(A.flatten(),P.flatten())  
Z_ollie = Z_ollie.reshape(n1,n2)

Z_ollie_masked = np.where(P > PSEP+np.ones_like(PSEP)*deltap, Z_ollie, np.nan)


rel_diff = np.abs((Z_ollie_masked - Z_nex_masked)/Z_ollie_masked)

fig, ax = plt.subplots(1,1,figsize = (10,6))
lvls =500

x1 = np.log10(np.abs(P-PSEP))
x2 = P-PSEP
cf1 = ax.contourf(x1, np.log10(1-A), rel_diff, levels=lvls, cmap="viridis")
cb = fig.colorbar(cf1, ax=ax,pad = 0.01)
cb.set_label(r"$\left|\frac{\dot{E}_{FEW}-\dot{E}_{zach}}{\dot{E}_{FEW}}\right|$", rotation =0 ,
             labelpad=-250,fontsize=20,     bbox=dict(boxstyle="square", edgecolor="black", facecolor="white")
            )

cb.ax.yaxis.set_label_coords(-4, 0.2)
ax.set_xlim(-1.628,-0.25)

ax.set_xlabel(r"$log_{10}$(p-$p_{sep}$)")
ax.set_ylabel(r"$log_{10}$(1-a)")

plt.suptitle("Relative difference between Zachs and FEW circular data (e=0)          ")
plt.show()
#fig.savefig(f"contourplot_a_vs_p_e=0_rel_diff_zach_FEW.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Convert ollies to pdot and edot

# %%
Edot = np.asarray(df["Edot_tot"])
agrid = np.asarray(df["a"])
pgrid = np.asarray(df["p"])
egrid = np.zeros_like(agrid)
xgrid = np.sign(agrid)
xgrid[xgrid == 0] = 1

freq , _,_ = get_fundamental_frequencies(agrid,pgrid,egrid,xgrid)

# %%
Edothere = Edot.flatten()
Ldothere = Edothere*freq

out_pdot_edot = np.asarray(
    [
        ELdot_to_PEdot_Jacobian(
            agrid[i],
            pgrid[i],
            egrid[i],
            xgrid[i],
            Edothere[i],
            Ldothere[i],
        )
        for i in range(Edothere.size)
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 5
#       1 Edothere = Edot.flatten()
#       2 Ldothere = Edothere*freq
#       3
#       4 out_pdot_edot = np.asarray(
# ----> 5     [
#       6         ELdot_to_PEdot_Jacobian(
#       7             agrid[i],
#       8             pgrid[i],
#
# ZeroDivisionError: division by zero

# %%
for i in range(len(Edothere)):
    print(i,
    agrid[i],
    pgrid[i],
    egrid[i],
    xgrid[i],
    Edothere[i],
    Ldothere[i],
          ELdot_to_PEdot_Jacobian(
            agrid[i],
            pgrid[i],
            egrid[i],
            xgrid[i],
            Edothere[i],
            Ldothere[i],
        ))
# Out:
# 0 0.97 1.6141 0.0 1.0 0.08102520126403089 0.026823591019121365 (-3.316387549998277, 0.0)
# 1 0.97 1.65 0.0 1.0 0.07658147412636471 0.02478795338186289 (-5.093724562680999, 0.0)
# 2 0.97 1.7 0.0 1.0 0.0708507838311821 0.022234471389714093 (-13.178944365213667, 0.0)
# 3 0.97 1.75 0.0 1.0 0.0655821843663715 0.01996393838387698 (43.27695149307052, 0.0)
# 4 0.97 1.8 0.0 1.0 0.0607228037283554 0.01793903675209136 (9.330821947165482, 0.0)
# 5 0.97 1.9 0.0 1.0 0.052086675025417285 0.014512990000747763 (4.055950046686894, 0.0)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[21], line 9
#       5     egrid[i],
#       6     xgrid[i],
#       7     Edothere[i],
#       8     Ldothere[i],
# ----> 9           ELdot_to_PEdot_Jacobian(
#      10             agrid[i],
#      11             pgrid[i],
#      12             egrid[i],
#
# ZeroDivisionError: division by zero

# %%
a,p,e,x = 0.999999,1.3,0,1

frq,_,_ = get_fundamental_frequencies(a,p,e,x)

nex_ELdot(a,p,e,x)[0], nex_ELdot(a,p,e,x)[1]*frq
# Out:
# (-0.08747760772634317, -0.08738953761669044)
