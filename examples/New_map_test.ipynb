# %%
from few.utils.mappings.kerrecceq import kerrecceq_forward_map

# %%
a,p,e,x = 0.9999,4,0.3,1

kerrecceq_forward_map(a,p,e,x,return_mask=True)
# Out:
# (array([0.7356924]),
#  array([0.75]),
#  array([1.]),
#  array([0.88888901]),
#  [array([False]), array([False]), array([ True])])
